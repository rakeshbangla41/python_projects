# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %% [markdown]
# ##### Dateset: Alcohol Beverages

# %%
drinks = pd.read_csv('drinks.csv')
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# ##### Q) Which continent drinks more beer on average?

# %%
drinks.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
continents = drinks.groupby(by='continent')
for continent, group in continents:
    print(continent)
    print(group)
    print('-------------------------------------------------------------------------------------')
# Out:
# AF
#                       country  beer_servings  spirit_servings  wine_servings  \
# 2                     Algeria             25                0             14
# 4                      Angola            217               57             45
# 18                      Benin             34                4             13
# 22                   Botswana            173               35             35
# 26               Burkina Faso             25                7              7
# 27                    Burundi             88                0              0
# 28              Cote d'Ivoire             37                1              7
# 29                 Cabo Verde            144               56             16
# 31                   Cameroon            147                1              4
# 33   Central African Republic             17                2              1
# 34                       Chad             15                1              1
# ...

# %%
continents.dtypes
# Out:
#           country beer_servings spirit_servings wine_servings  \
# continent
# AF         object         int64           int64         int64
# AS         object         int64           int64         int64
# EU         object         int64           int64         int64
# OC         object         int64           int64         int64
# SA         object         int64           int64         int64
#
#           total_litres_of_pure_alcohol
# continent
# AF                             float64
# AS                             float64
# EU                             float64
# OC                             float64
# SA                             float64

# %%
continents['beer_servings'].mean()
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %% [markdown]
# People from EU drink more beer on an average at 193.77 litres

# %% [markdown]
# ##### Q) For each continent print the statistics for wine consumption.

# %%
continents.describe()
# Out:
#           beer_servings                                                      \
#                   count        mean        std   min     25%    50%     75%
# continent
# AF                 53.0   61.471698  80.557816   0.0   15.00   32.0   76.00
# AS                 44.0   37.045455  49.469725   0.0    4.25   17.5   60.50
# EU                 45.0  193.777778  99.631569   0.0  127.00  219.0  270.00
# OC                 16.0   89.687500  96.641412   0.0   21.00   52.5  125.75
# SA                 12.0  175.083333  65.242845  93.0  129.50  162.5  198.00
#
#                  spirit_servings                                             \
#              max           count        mean        std   min    25%    50%
# continent
# AF         376.0            53.0   16.339623  28.102794   0.0   1.00    3.0
# AS         247.0            44.0   60.840909  84.362160   0.0   1.00   16.0
# EU         361.0            45.0  132.555556  77.589115   0.0  81.00  122.0
# ...

# %%
continents[['wine_servings']].describe()
# Out:
#           wine_servings                                                   \
#                   count        mean        std  min   25%    50%     75%
# continent
# AF                 53.0   16.264151  38.846419  0.0   1.0    2.0   13.00
# AS                 44.0    9.068182  21.667034  0.0   0.0    1.0    8.00
# EU                 45.0  142.222222  97.421738  0.0  59.0  128.0  195.00
# OC                 16.0   35.625000  64.555790  0.0   1.0    8.5   23.25
# SA                 12.0   62.416667  88.620189  1.0   3.0   12.0   98.50
#
#
#              max
# continent
# AF         233.0
# AS         123.0
# EU         370.0
# OC         212.0
# SA         221.0

# %% [markdown]
# ##### Q) Print the mean alcohol consumption per continent for every column

# %%
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
continents['total_litres_of_pure_alcohol'].mean()
# Out:
# continent
# AF    3.007547
# AS    2.170455
# EU    8.617778
# OC    3.381250
# SA    6.308333
# Name: total_litres_of_pure_alcohol, dtype: float64

# %%
continents.mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %% [markdown]
# ##### Q) Print the median alcohol consumption per continent for every column

# %%
continents.median()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  32.0              3.0            2.0
# AS                  17.5             16.0            1.0
# EU                 219.0            122.0          128.0
# OC                  52.5             37.0            8.5
# SA                 162.5            108.5           12.0
#
#            total_litres_of_pure_alcohol
# continent
# AF                                 2.30
# AS                                 1.20
# EU                                10.00
# OC                                 1.75
# SA                                 6.85

# %% [markdown]
# ##### Q) Print the mean, min and max values for spirit consumption.
# #### This time output a DataFrame

# %%
continents[['spirit_servings']].describe()
# Out:
#           spirit_servings                                                     \
#                     count        mean        std   min    25%    50%     75%
# continent
# AF                   53.0   16.339623  28.102794   0.0   1.00    3.0   19.00
# AS                   44.0   60.840909  84.362160   0.0   1.00   16.0   98.00
# EU                   45.0  132.555556  77.589115   0.0  81.00  122.0  173.00
# OC                   16.0   58.437500  70.504817   0.0  18.00   37.0   65.25
# SA                   12.0  114.750000  77.077440  25.0  65.75  108.5  148.75
#
#
#              max
# continent
# AF         152.0
# AS         326.0
# EU         373.0
# OC         254.0
# SA         302.0

# %%
continents[['spirit_servings']].agg(['mean', 'min', 'max'])
# Out:
#           spirit_servings
#                      mean min  max
# continent
# AF              16.339623   0  152
# AS              60.840909   0  326
# EU             132.555556   0  373
# OC              58.437500   0  254
# SA             114.750000  25  302
