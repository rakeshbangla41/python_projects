# %% [markdown]
# **Consider the following Python dictionary data and Python list labels:**
#
# data = {'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills'],
#         'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4],
#         'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **1. Create a DataFrame birds from this dictionary data which has the index labels.**

# %%
data = {'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills'], 'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4], 'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2], 'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

# %%
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
birds = pd.DataFrame(data, columns=['birds', 'age', 'visits', 'priority'], index=labels)

# %%
birds
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %%
############################################################################

# %% [markdown]
# **2. Display a summary of the basic information about birds DataFrame and its data.**

# %%
birds.describe()
# Out:
#             age     visits
# count  8.000000  10.000000
# mean   4.437500   2.900000
# std    2.007797   0.875595
# min    1.500000   2.000000
# 25%    3.375000   2.000000
# 50%    4.000000   3.000000
# 75%    5.625000   3.750000
# max    8.000000   4.000000

# %%
############################################################################

# %% [markdown]
# **3. Print the first 2 rows of the birds dataframe**

# %%
birds.head(2)
# Out:
#     birds  age  visits priority
# a  Cranes  3.5       2      yes
# b  Cranes  4.0       4      yes

# %%
############################################################################

# %% [markdown]
# **4. Print all the rows with only 'birds' and 'age' columns from the dataframe**

# %%
birds[['birds', 'age']]
# Out:
#         birds  age
# a      Cranes  3.5
# b      Cranes  4.0
# c     plovers  1.5
# d  spoonbills  NaN
# e  spoonbills  6.0
# f      Cranes  3.0
# g     plovers  5.5
# h      Cranes  NaN
# i  spoonbills  8.0
# j  spoonbills  4.0

# %%
############################################################################

# %% [markdown]
# **5. select [2, 3, 7] rows and in columns ['birds', 'age', 'visits']**

# %%
birds.shape
# Out:
# (10, 4)

# %%
#references:
#https://www.google.co.in/search?q=how+to+select+rows+based+on+index+pandas&sxsrf=AOaemvLh99Gi-5XwaOw-dkP9uubOkqD95Q%3A1634539181657&source=hp&ei=rRZtYY_oJcDV1sQPlpipiAE&iflsig=ALs-wAMAAAAAYW0kvY_ZAC7EnGhDi2cdKoefNFPkUlee&oq=how+to+select+rows+based+on+index+pandas&gs_lcp=Cgdnd3Mtd2l6EAMYATIECAAQDTIGCAAQFhAeMgYIABAWEB46BAgjECc6CgguEMcBEK8BECc6CAgAEIAEELEDOgUILhCABDoLCAAQgAQQsQMQgwE6BQgAEIAEOggILhCxAxCDAToFCAAQsQM6CAguEIAEEJMCULEEWNRWYObDAWgAcAB4AYAB7ASIAYgakgEIMS4yMi41LTGYAQCgAQE&sclient=gws-wiz
#https://stackoverflow.com/questions/19155718/select-pandas-rows-based-on-list-index/19295539
#https://www.geeksforgeeks.org/select-rows-columns-by-name-or-index-in-pandas-dataframe-using-loc-iloc/

# %%
#other way:
#index_list = ['b', 'c', 'g']
#birds.loc[index_list]

# %%
birds.loc[['b', 'c', 'g'], ['birds', 'age', 'visits']]
# Out:
#      birds  age  visits
# b   Cranes  4.0       4
# c  plovers  1.5       3
# g  plovers  5.5       2

# %%
############################################################################

# %% [markdown]
# **6. select the rows where the number of visits is less than 4**

# %%
birds[birds['visits'] < 4]
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# c     plovers  1.5       3       no
# e  spoonbills  6.0       3       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %%
############################################################################

# %% [markdown]
# **7. select the rows with columns ['birds', 'visits'] where the age is missing i.e NaN**

# %%
birds.dtypes
# Out:
# birds        object
# age         float64
# visits        int64
# priority     object
# dtype: object

# %%
#replacing/filling NaN values with 0
birds_no_nan_values = birds.fillna(0)
birds_no_nan_values
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  0.0       4      yes
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  0.0       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %%
birds_no_nan_values[['birds', 'visits']][birds_no_nan_values['age'] == 0.0]
# Out:
#         birds  visits
# d  spoonbills       4
# h      Cranes       2

# %%
############################################################################

# %% [markdown]
# **8. Select the rows where the birds is a Cranes and the age is less than 4**

# %%
#how to select rows based on condition in pandas
#https://www.geeksforgeeks.org/how-to-select-rows-from-a-dataframe-based-on-column-values/
li = ['Cranes']
li2 = [4]
birds[(birds.birds.isin(li)) & (~birds.age.isin(li2)) ]
# Out:
#     birds  age  visits priority
# a  Cranes  3.5       2      yes
# f  Cranes  3.0       4       no
# h  Cranes  NaN       2      yes

# %%
############################################################################

# %% [markdown]
# **9. Select the rows where the age is between 2 and 4(inclusive)**

# %%
birds[(birds['age'] >= 2) & (birds['age'] <= 4)]
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# f      Cranes  3.0       4       no
# j  spoonbills  4.0       2       no

# %%
############################################################################

# %% [markdown]
# **10. Find the total number of visits of the bird Cranes**

# %%
k = birds.loc[birds['birds'] == 'Cranes',['visits']].sum(axis=1)
k
# Out:
# a    2
# b    4
# f    4
# h    2
# dtype: int64

# %%
g = k.sum()
print(f'Total number of visits of the bird Cranes is {g}')
# Out:
# Total number of visits of the bird Cranes is 12

# %%
birds.loc[birds['birds'] == 'Cranes',['visits']].sum(axis=1).sum()
# Out:
# 12

# %%
############################################################################

# %% [markdown]
# **11. Calculate the mean age for each different birds in dataframe.**

# %%
birds
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %%
#birds[birds['birds'] == 'Cranes'].mean()

# %%
w = birds[birds['birds'] == 'Cranes'].age.mean()
e = birds[birds['birds'] == 'plovers'].age.mean()
r = birds[birds['birds'] == 'spoonbills'].age.mean()
print(f'Mean age of Cranes: {w}')
print(f'Mean age of plovers: {e}')    
print(f'Mean age of spoonbills: {r}')
# Out:
# Mean age of Cranes: 3.5
# Mean age of plovers: 3.5
# Mean age of spoonbills: 6.0

# %%
############################################################################

# %% [markdown]
# **12. Append a new row 'k' to dataframe with your choice of values for each column. Then delete that row to return the original DataFrame.**

# %%
birds
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %%
p = pd.Series({'birds': 'plovers', 'age': 3.0, 'visits': 2, 'priority': 'no'}, name='k')
p
# Out:
# birds       plovers
# age             3.0
# visits            2
# priority         no
# Name: k, dtype: object

# %%
m = birds.append(p)
m
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no
# k     plovers  3.0       2       no

# %%
m.drop('k')
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %%
############################################################################

# %% [markdown]
# **13. Find the number of each type of birds in dataframe (Counts)**

# %%
c = birds[birds['birds'] == 'Cranes']
c1 = c.birds.count()
print(f'Number of Cranes: {c1}')

d = birds[birds['birds'] == 'plovers']
d1 = d.birds.count()
print(f'Number of plovers: {d1}')

e = birds[birds['birds'] == 'spoonbills']
e1 = e.birds.count()
print(f'Number of spoonbills: {e1}')
# Out:
# Number of Cranes: 4
# Number of plovers: 2
# Number of spoonbills: 4

# %%
############################################################################

# %% [markdown]
# **14. Sort dataframe (birds) first by the values in the 'age' in decending order, then by the value in the 'visits' column in ascending order.**

# %%
birds
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %%
descen = birds.sort_values(by = 'age', ascending = False)
descen
# Out:
#         birds  age  visits priority
# i  spoonbills  8.0       3       no
# e  spoonbills  6.0       3       no
# g     plovers  5.5       2       no
# b      Cranes  4.0       4      yes
# j  spoonbills  4.0       2       no
# a      Cranes  3.5       2      yes
# f      Cranes  3.0       4       no
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# h      Cranes  NaN       2      yes

# %%
ascen = birds.sort_values(by = 'visits', ascending = True)
ascen
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# j  spoonbills  4.0       2       no
# c     plovers  1.5       3       no
# e  spoonbills  6.0       3       no
# i  spoonbills  8.0       3       no
# b      Cranes  4.0       4      yes
# d  spoonbills  NaN       4      yes
# f      Cranes  3.0       4       no

# %%
############################################################################

# %% [markdown]
# **15. Replace the priority column values with'yes' should be 1 and 'no' should be 0**

# %%
#l = birds[birds['priority'] == 'yes']
#u = l.replace('yes', 1)

# %%
y = birds.replace(['yes', 'no'],[1,0])
y
# Out:
#         birds  age  visits  priority
# a      Cranes  3.5       2         1
# b      Cranes  4.0       4         1
# c     plovers  1.5       3         0
# d  spoonbills  NaN       4         1
# e  spoonbills  6.0       3         0
# f      Cranes  3.0       4         0
# g     plovers  5.5       2         0
# h      Cranes  NaN       2         1
# i  spoonbills  8.0       3         0
# j  spoonbills  4.0       2         0

# %%
############################################################################

# %% [markdown]
# **16. In the 'birds' column, change the 'Cranes' entries to 'trumpeters'.**

# %%
i = birds.replace('Cranes', 'trumpeters')
i
# Out:
#         birds  age  visits priority
# a  trumpeters  3.5       2      yes
# b  trumpeters  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# e  spoonbills  6.0       3       no
# f  trumpeters  3.0       4       no
# g     plovers  5.5       2       no
# h  trumpeters  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %%
############################################################################
